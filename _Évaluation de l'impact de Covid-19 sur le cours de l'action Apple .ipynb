# %% [markdown]
#    # Stock Market Analysis

# %% [markdown]
# # Évaluation de l'impact de Covid-19 sur le cours de l'action Apple Inc

# %% [markdown]
# # ![trading.PNG](attachment:trading.PNG)

# %% [markdown]
# # Chargements des bibliothéques à utiliser:

# %% [markdown]
# # 1- Numpy :

# %% [markdown]
# => Numpy est une bibliotheque qui permet d'effectuer des calculs numerique avec Python , tableaux des nombres :

# %%
import numpy as np

# %% [markdown]
# # 2- Pandas :

# %% [markdown]
# => Panda est une librairie qui permet de manipuler facilement des données à analyser :
# les tableaux sont les DATA FRAMES

# %%
import pandas as pd

# %% [markdown]
# # 3- Matplotlib :

# %% [markdown]
# => Matplotlib est une bibliotheque qui permet de visualiser les données :

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 4- Seaborn :

# %% [markdown]
# => Seaborn est une bibliothèque de visualisation de données Python basée sur matplotlib :

# %%
import seaborn as sns

# %% [markdown]
# # Prétraiter les données pour le machine learning:

# %% [markdown]
# Cette section présente les opérations de prétraitement des données et les étapes relatives à leur préparation.

# %% [markdown]
# # Extraction de données:

# %% [markdown]
# # Données brutes

# %%
#read:
aapl_2019 = pd.read_csv('AAPL-2019.csv')

# %% [markdown]
# # Visualisation des données:

# %% [markdown]
# # Comprendre les données

# %% [markdown]
# Affichage de cinq premières lignes de la base de données:

# %%
#head:
aapl_2019.head()
# Out:
#          Date        Low       Open       Volume       High      Close  \
# 0  02-01-2019  38.557499  38.722500  148158800.0  39.712502  39.480000
# 1  03-01-2019  35.500000  35.994999  365248800.0  36.430000  35.547501
# 2  04-01-2019  35.950001  36.132500  234428400.0  37.137501  37.064999
# 3  07-01-2019  36.474998  37.174999  219111200.0  37.207500  36.982498
# 4  08-01-2019  37.130001  37.389999  164101200.0  37.955002  37.687500
#
#    Adjusted Close
# 0       38.505024
# 1       34.669640
# 2       36.149662
# 3       36.069202
# 4       36.756794

# %% [markdown]
# Affichage de cinq dernières lignes de la base de données:

# %%
#tail:
aapl_2019.tail()
# Out:
#            Date        Low       Open       Volume       High      Close  \
# 247  24-12-2019  70.730003  71.172501   48478800.0  71.222504  71.067497
# 248  26-12-2019  71.175003  71.205002   93121200.0  72.495003  72.477501
# 249  27-12-2019  72.029999  72.779999  146266000.0  73.492500  72.449997
# 250  30-12-2019  71.305000  72.364998  144114400.0  73.172501  72.879997
# 251  31-12-2019  72.379997  72.482498  100805600.0  73.419998  73.412498
#
#      Adjusted Close
# 247       70.353882
# 248       71.749733
# 249       71.722488
# 250       72.148178
# 251       72.675339

# %% [markdown]
# décrire toutes les variables quantitatives d'un jeu de données directement:

# %%
#describe:
aapl_2019.describe()
# Out:
#               Low        Open        Volume        High       Close  \
# count  252.000000  252.000000  2.520000e+02  252.000000  252.000000
# mean    51.567907   51.967272  1.121228e+08   52.457927   52.063988
# std      8.576434    8.593396  4.329647e+07    8.621376    8.634745
# min     35.500000   35.994999  4.544800e+07   36.430000   35.547501
# 25%     45.879376   46.281876  8.390080e+07   46.958125   46.504999
# 50%     50.398750   50.785000  1.035100e+08   51.178751   50.753750
# 75%     55.326874   55.873750  1.280795e+08   56.260000   55.921249
# max     72.379997   72.779999  3.652488e+08   73.492500   73.412498
#
#        Adjusted Close
# count      252.000000
# mean        51.234448
# std          8.709443
# min         34.669640
# 25%         45.633443
# 50%         49.938271
# 75%         55.194013
# max         72.675339

# %% [markdown]
# Affichage plus de détails et info sur la base:

# %%
#info:
aapl_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 7 columns):
# Date              252 non-null object
# Low               252 non-null float64
# Open              252 non-null float64
# Volume            252 non-null float64
# High              252 non-null float64
# Close             252 non-null float64
# Adjusted Close    252 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 13.9+ KB

# %% [markdown]
# détecte la ou les valeurs manquantent :

# %%
#isnull:
aapl_2019.isnull().any()
# Out:
# Date              False
# Low               False
# Open              False
# Volume            False
# High              False
# Close             False
# Adjusted Close    False
# dtype: bool

# %% [markdown]
# la corrélation entre plusieurs variables aléatoires ou statistiques est une notion de liaison qui contredit leur indépendance.

# %%
#describing correlation
corr=aapl_2019.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,vmin=-1, vmax=1, annot=True ,cmap='summer')
plt.title('Correlation Heatmap / APPL 2019', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap / APPL 2019')

# %% [markdown]
# le caractere Volume a une faible correlation avec les autres caracters

# %% [markdown]
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset

# %%
sns.kdeplot(aapl_2019.Volume, shade=True)
plt.show()

# %% [markdown]
# Plot pairwise relationships in a dataset

# %%
sns.pairplot(aapl_2019, kind='reg')

# %% [markdown]
# # Analyse graphique pour tous les caracteres :

# %%
# Visually show the stock price / Low Price History
plt.figure(figsize=(15,10))
plt.plot(aapl_2019['Low'], label='Low ', alpha=1)
plt.title('APPL Low Price History')
plt.xlabel('Date')
plt.ylabel('Low Price USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# Visually show the stock price / Open Price History
plt.figure(figsize=(15,10))
plt.plot(aapl_2019['Open'], label='Open ', alpha=1)
plt.title('APPL Open Price History')
plt.xlabel('Date')
plt.ylabel('Open Price USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()


# Visually show the stock price / Volume 
plt.figure(figsize=(15,10))
plt.plot(aapl_2019['Volume'], label='Volume ', alpha=1)
plt.title('APPL Volume History')
plt.xlabel('Date')
plt.ylabel('Volume USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()


# Visually show the stock price / High 
plt.figure(figsize=(15,10))
plt.plot(aapl_2019['High'], label='High ', alpha=1)
plt.title('APPL High Price History')
plt.xlabel('Date')
plt.ylabel('High Price USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# Visually show the stock price / Close
plt.figure(figsize=(15,10))
plt.plot(aapl_2019['Close'], label='Close', alpha=1)
plt.title('APPL Close Price History')
plt.xlabel('Date')
plt.ylabel('Close Price USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# Visually show the stock price / Adjusted Close
plt.figure(figsize=(15,10))
plt.plot(aapl_2019['Adjusted Close'], label='Adjusted Close', alpha=1)
plt.title('APPL Adjusted Close Price History')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Nettoyage Des données:

# %%
AAPL_2019 = aapl_2019['Close']

# %% [markdown]
# # Affichage des données nettoyées:

# %%
AAPL_2019.head()
# Out:
# 0    39.480000
# 1    35.547501
# 2    37.064999
# 3    36.982498
# 4    37.687500
# Name: Close, dtype: float64

# %%
AAPL_2019.tail()
# Out:
# 247    71.067497
# 248    72.477501
# 249    72.449997
# 250    72.879997
# 251    73.412498
# Name: Close, dtype: float64

# %% [markdown]
# # Transformation des données en Data Frame:

# %%
AAPL_2019 = pd.DataFrame(AAPL_2019)

# %% [markdown]
# # Prediction 50 days into the future

# %%
future_days = 50
AAPL_2019['Prediction'] = AAPL_2019['Close'].shift(-future_days)

# %%
AAPL_2019.head()
# Out:
#        Close  Prediction
# 0  39.480000   46.529999
# 1  35.547501   47.005001
# 2  37.064999   46.632500
# 3  36.982498   47.040001
# 4  37.687500   48.772499

# %%
AAPL_2019.tail()
# Out:
#          Close  Prediction
# 247  71.067497         NaN
# 248  72.477501         NaN
# 249  72.449997         NaN
# 250  72.879997         NaN
# 251  73.412498         NaN

# %% [markdown]
# Creation d'un tableau  qui porte les cours sans les Predictions:

# %%
X = np.array(AAPL_2019.drop(['Prediction'], 1))[:-future_days]
print(X)
# Out:
# [[39.47999954]
#  [35.54750061]
#  [37.06499863]
#  [36.98249817]
#  [37.6875    ]
#  [38.32749939]
#  [38.45000076]
#  [38.07249832]
#  [37.5       ]
#  [38.26750183]
#  [38.73500061]
#  [38.96500015]
#  [39.20500183]
#  [38.32500076]
#  [38.47999954]
#  [38.17499924]
#  [39.43999863]
#  [39.07500076]
#  [38.66999817]
#  [41.3125    ]
#  [41.61000061]
#  [41.63000107]
#  [42.8125    ]
#  [43.54499817]
#  [43.56000137]
#  [42.73500061]
#  [42.60250092]
#  [42.35749817]
#  [42.72249985]
#  [42.54499817]
#  [42.70000076]
#  [42.60499954]
#  [42.73249817]
#  [43.00749969]
#  [42.76499939]
#  [43.24250031]
#  [43.55749893]
#  [43.58250046]
#  [43.71749878]
#  [43.28749847]
#  [43.74250031]
#  [43.96250153]
#  [43.88249969]
#  [43.63000107]
#  [43.125     ]
#  [43.22750092]
#  [44.72499847]
#  [45.22750092]
#  [45.42750168]
#  [45.93249893]
#  [46.52999878]
#  [47.00500107]
#  [46.63249969]
#  [47.04000092]
#  [48.77249908]
#  [47.76250076]
#  [47.18500137]
#  [46.69749832]
# ...

# %%
#la taille du tableau:
X.shape
# Out:
# (202, 1)

# %% [markdown]
# Creation d'un tableau  qui porte les Predictions sans les cours :

# %%
y = np.array(AAPL_2019['Prediction'])[:-future_days]
print(y)
# Out:
# [46.52999878 47.00500107 46.63249969 47.04000092 48.77249908 47.76250076
#  47.18500137 46.69749832 47.11750031 47.18000031 47.48749924 47.81000137
#  48.50500107 48.83750153 48.92250061 49.25       50.02500153 49.875
#  50.15499878 49.73749924 49.71749878 49.80749893 49.8125     50.78250122
#  50.96500015 51.13249969 51.86999893 51.79000092 51.31999969 51.07500076
#  51.15250015 50.16749954 52.63000107 52.28749847 52.9375     52.11999893
#  50.71500015 50.72499847 50.18000031 49.29499817 46.43000031 47.16500092
#  47.72999954 47.52000046 47.25       45.77249908 46.65000153 45.69499969
#  44.91500092 44.74250031 44.55749893 44.34500122 44.57500076 43.76750183
#  43.32500076 44.90999985 45.63499832 46.30500031 47.53749847 48.14500046
#  48.70249939 48.54750061 48.53749847 48.18500137 48.47249985 49.61249924
#  49.46749878 49.86500168 49.69499969 49.64500046 48.89250183 49.95000076
#  49.93500137 49.47999954 50.38750076 50.68249893 51.10250092 51.05749893
# ...

# %%
#taille du tableau:
y.shape
# Out:
# (202,)

# %% [markdown]
# # Split Dataset (Training and Test) :

# %% [markdown]
# # Chargements des bibliothéques à utiliser:

# %% [markdown]
# # Sklearn :

# %% [markdown]
# => Sklearn est une bibliotheque d'apprentissage automatique

# %% [markdown]
# Train test plit : x_train , x_test , y_train , y_test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %% [markdown]
# # linearRegression:

# %%
#linearRegression:
from sklearn.linear_model import LinearRegression

# %%
# Implementing Linear Regression Algorithms.
lr = LinearRegression().fit(x_train, y_train)

# %%
x_future = AAPL_2019.drop(['Prediction'], 1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
x_future
# Out:
# array([[50.24750137],
#        [50.11999893],
#        [52.24250031],
#        [50.6875    ],
#        [50.43500137],
#        [51.625     ],
#        [52.58750153],
#        [52.59000015],
#        [53.15999985],
#        [53.11500168],
#        [50.65999985],
#        [51.62250137],
#        [51.04000092],
#        [51.38249969],
#        [52.25249863],
#        [52.18500137],
#        [51.42499924],
#        [52.29750061],
#        [53.31999969],
#        [53.31499863],
#        [53.54249954],
#        [54.17499924],
#        [55.89749908],
#        [55.77249908],
#        [54.6875    ],
#        [54.97499847],
#        [55.17499924],
#        [55.69250107],
#        [55.24000168],
#        [54.43249893],
#        [54.68000031],
#        [54.41999817],
#        [55.25749969],
#        [54.97249985],
#        [54.70500183],
#        [55.99250031],
#        [56.14749908],
#        [54.74000168],
#        [55.20500183],
#        [56.75249863],
#        [56.76499939],
# ...

# %% [markdown]
# # Prediction:

# %%
lr_prediction = lr.predict(x_future)
print(lr_prediction)
# Out:
# [56.54382043 56.39757513 58.83208432 57.04849888 56.75888294 58.12381144
#  59.22780074 59.23066667 59.88445635 59.83284345 57.01695621 58.12094551
#  57.45281745 57.84566357 58.8435524  58.76613304 57.89441055 58.89516967
#  60.06797618 60.06223996 60.32318352 61.04866071 63.02436813 62.88099312
#  61.63649911 61.96625988 62.19566076 62.78923539 62.27021857 61.34401287
#  61.62789696 61.3296745  62.29028879 61.96339395 61.65657371 63.13333453
#  63.31111814 61.69671854 62.23007374 64.00505265 64.01939103 63.25663494
#  64.01078888 64.88824322 66.64315628 66.54565795 66.38794895 66.11553293
#  66.3764765  66.70050541]

# %% [markdown]
# # Validation

# %%
predictions = lr_prediction
valid = AAPL_2019[(X.shape[0]):]
valid['Predictions'] = predictions
# Out:
# C:\Users\ASUS\AppData\Local\conda\conda\envs\HCIA_AI\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # Graphique : Original , valide , prediction :

# %%
plt.figure(figsize=(15,10))
plt.title("Apple's Stock Price Prediction Model(Linear Regression Model)")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
plt.plot(AAPL_2019['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(["Original", "Valid", 'Predicted'])
plt.show()

# %% [markdown]
# # Courbe de cours :

# %%
# Visually show the stock price / Close
plt.figure(figsize=(15,10))
plt.plot(aapl_2019['Close'], label='Close', alpha=1)
plt.title('APPL Close Price History')
plt.xlabel('Date')
plt.ylabel('Close Price USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Visualisation de Y test et Y Predict

# %%
sns.kdeplot(y_test, shade=True)
sns.kdeplot(y, shade=True)

# %% [markdown]
# Visualisation du test et train :

# %%
plt.figure(figsize=(10,7))
#scatterplot for both set of data
plt.scatter(x_test, y_test, color='green',label='test')
plt.scatter(x_train, y_train, color='blue',label='train')

# %% [markdown]
# # Chargements des bibliothéques à utiliser:

# %% [markdown]
# # Sklearn

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# Implementing DecisionTreeRegressor.

# %%
tree = DecisionTreeRegressor().fit(x_train, y_train)

# %%
x_future = AAPL_2019.drop(['Prediction'], 1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
x_future
# Out:
# array([[50.24750137],
#        [50.11999893],
#        [52.24250031],
#        [50.6875    ],
#        [50.43500137],
#        [51.625     ],
#        [52.58750153],
#        [52.59000015],
#        [53.15999985],
#        [53.11500168],
#        [50.65999985],
#        [51.62250137],
#        [51.04000092],
#        [51.38249969],
#        [52.25249863],
#        [52.18500137],
#        [51.42499924],
#        [52.29750061],
#        [53.31999969],
#        [53.31499863],
#        [53.54249954],
#        [54.17499924],
#        [55.89749908],
#        [55.77249908],
#        [54.6875    ],
#        [54.97499847],
#        [55.17499924],
#        [55.69250107],
#        [55.24000168],
#        [54.43249893],
#        [54.68000031],
#        [54.41999817],
#        [55.25749969],
#        [54.97249985],
#        [54.70500183],
#        [55.99250031],
#        [56.14749908],
#        [54.74000168],
#        [55.20500183],
#        [56.75249863],
#        [56.76499939],
# ...

# %% [markdown]
# # Prediction:

# %%
tree_prediction = tree.predict(x_future)
print(tree_prediction)
# Out:
# [60.12749863 59.99000168 65.03500366 60.89500046 54.43249893 62.26250076
#  60.82249832 60.81499863 62.18999863 62.18999863 64.375      64.28250122
#  64.30999756 64.85749817 65.03500366 65.55000305 54.70500183 66.11750031
#  66.44000244 66.44000244 66.44000244 65.43499756 67.12000275 65.50250244
#  64.86250305 66.59249878 66.07250214 66.95999908 66.8125     66.04000092
#  64.86250305 65.43499756 66.39499664 67.67749786 66.73000336 67.12000275
#  67.69249725 67.86499786 66.07250214 70.00499725 70.10250092 69.93499756
#  70.00499725 69.86000061 71.         71.06749725 72.47750092 72.44999695
#  72.47750092 73.41249847]

# %% [markdown]
# # Validation :

# %%
predictions = tree_prediction 
valid = AAPL_2019[X.shape[0]:]
valid['Predictions'] = predictions
# Out:
# C:\Users\ASUS\AppData\Local\conda\conda\envs\HCIA_AI\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # visualisation de : original , Valid et Predicted :

# %%
plt.figure(figsize=(12,8))
plt.title("Apple's Stock Price Prediction Model(Decision Tree Regressor Model)")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
plt.plot(AAPL_2019['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(["Original", "Valid", 'Predicted'])
plt.show()

# %% [markdown]
# # courbe de cours :

# %%
# Visually show the stock price / Close
plt.figure(figsize=(15,10))
plt.plot(aapl_2019['Close'], label='Close', alpha=1)
plt.title('APPL Close Price History')
plt.xlabel('Date')
plt.ylabel('Close Price USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # visualisation de : y test et y predicted

# %%
sns.kdeplot(y_test, shade=True)
sns.kdeplot(y, shade=True)

# %% [markdown]
# # AAPL 2020 / COVID-19

# %%
aapl_2020 = pd.read_csv('AAPL-2020.csv')

# %%
aapl_2020.head()
# Out:
#          Date        Low       Open       Volume       High      Close  \
# 0  02-01-2020  73.797501  74.059998  135480400.0  75.150002  75.087502
# 1  03-01-2020  74.125000  74.287498  146322800.0  75.144997  74.357498
# 2  06-01-2020  73.187500  73.447502  118387200.0  74.989998  74.949997
# 3  07-01-2020  74.370003  74.959999  108872000.0  75.224998  74.597504
# 4  08-01-2020  74.290001  74.290001  132079200.0  76.110001  75.797501
#
#    Adjusted Close
# 0       74.333511
# 1       73.610840
# 2       74.197395
# 3       73.848442
# 4       75.036385

# %%
aapl_2020.tail()
# Out:
#            Date         Low        Open       Volume        High       Close  \
# 248  24-12-2020  131.100006  131.320007   54930100.0  133.460007  131.970001
# 249  28-12-2020  133.509995  133.990005  124486200.0  137.339996  136.690002
# 250  29-12-2020  134.339996  138.050003  121047300.0  138.789993  134.869995
# 251  30-12-2020  133.399994  135.580002   96452100.0  135.990005  133.720001
# 252  31-12-2020  131.720001  134.080002   99116600.0  134.740005  132.690002
#
#      Adjusted Close
# 248      131.773087
# 249      136.486053
# 250      134.668762
# 251      133.520477
# 252      132.492020

# %%
aapl_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 7 columns):
# Date              253 non-null object
# Low               253 non-null float64
# Open              253 non-null float64
# Volume            253 non-null float64
# High              253 non-null float64
# Close             253 non-null float64
# Adjusted Close    253 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 13.9+ KB

# %%
aapl_2020.describe()
# Out:
#               Low        Open        Volume        High       Close  \
# count  253.000000  253.000000  2.530000e+02  253.000000  253.000000
# mean    93.912796   95.267668  1.575816e+08   96.661769   95.347075
# std     21.579913   22.011907  6.983314e+07   22.094637   21.809814
# min     53.152500   57.020000  4.669130e+07   57.125000   56.092499
# 25%     76.220001   77.025002  1.108432e+08   78.167503   77.385002
# 50%     90.910004   91.279999  1.380234e+08   92.970001   91.632500
# 75%    114.129997  115.982498  1.875728e+08  117.279999  115.750000
# max    134.339996  138.050003  4.268848e+08  138.789993  136.690002
#
#        Adjusted Close
# count      253.000000
# mean        94.901985
# std         21.921424
# min         55.661041
# 25%         76.630219
# 50%         91.173805
# 75%        115.378235
# max        136.486053

# %%
aapl_2020.shape
# Out:
# (253, 7)

# %%
aapl_2020.isnull().any()
# Out:
# Date              False
# Low               False
# Open              False
# Volume            False
# High              False
# Close             False
# Adjusted Close    False
# dtype: bool

# %%
#describing correlation
corr=aapl_2020.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,vmin=-1, vmax=1, annot=True ,cmap='summer')
plt.title('Correlation Heatmap', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
sns.pairplot(aapl_2020, kind='reg')

# %%
# Visually show the stock price / Low Price History
plt.figure(figsize=(15,10))
plt.plot(aapl_2020['Low'], label='Low ', alpha=1)
plt.title('APPL Low Price History')
plt.xlabel('Date')
plt.ylabel('Low Price USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# Visually show the stock price / Open Price History
plt.figure(figsize=(15,10))
plt.plot(aapl_2020['Open'], label='Open ', alpha=1)
plt.title('APPL Open Price History')
plt.xlabel('Date')
plt.ylabel('Open Price USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()


# Visually show the stock price / Volume 
plt.figure(figsize=(15,10))
plt.plot(aapl_2020['Volume'], label='Volume ', alpha=1)
plt.title('APPL Volume History')
plt.xlabel('Date')
plt.ylabel('Volume USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()


# Visually show the stock price / High 
plt.figure(figsize=(15,10))
plt.plot(aapl_2020['High'], label='High ', alpha=1)
plt.title('APPL High Price History')
plt.xlabel('Date')
plt.ylabel('High Price USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# Visually show the stock price / Close
plt.figure(figsize=(15,10))
plt.plot(aapl_2020['Close'], label='Close', alpha=1)
plt.title('APPL Close Price History')
plt.xlabel('Date')
plt.ylabel('Close Price USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# Visually show the stock price / Adjusted Close
plt.figure(figsize=(15,10))
plt.plot(aapl_2020['Adjusted Close'], label='Adjusted Close', alpha=1)
plt.title('APPL Adjusted Close Price History')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %%
AAPL_2020 = aapl_2020['Close']

# %%
AAPL_2020.head()
# Out:
# 0    75.087502
# 1    74.357498
# 2    74.949997
# 3    74.597504
# 4    75.797501
# Name: Close, dtype: float64

# %%
AAPL_2020.tail()
# Out:
# 248    131.970001
# 249    136.690002
# 250    134.869995
# 251    133.720001
# 252    132.690002
# Name: Close, dtype: float64

# %%
AAPL_2020 = pd.DataFrame(AAPL_2020)

# %%
# Prediction 50 days into the future.
future_days = 50
AAPL_2020['Prediction'] = AAPL_2020['Close'].shift(-future_days)

# %%
AAPL_2020.tail()
# Out:
#           Close  Prediction
# 248  131.970001         NaN
# 249  136.690002         NaN
# 250  134.869995         NaN
# 251  133.720001         NaN
# 252  132.690002         NaN

# %%
X = np.array(AAPL_2020.drop(['Prediction'], 1))[:-future_days]
print(X)
# Out:
# [[ 75.08750153]
#  [ 74.35749817]
#  [ 74.94999695]
#  [ 74.59750366]
#  [ 75.79750061]
#  [ 77.40750122]
#  [ 77.58249664]
#  [ 79.23999786]
#  [ 78.16999817]
#  [ 77.83499908]
#  [ 78.80999756]
#  [ 79.68250275]
#  [ 79.14250183]
#  [ 79.42500305]
#  [ 79.80750275]
#  [ 79.57749939]
#  [ 77.23750305]
#  [ 79.42250061]
#  [ 81.08499908]
#  [ 80.96749878]
#  [ 77.37750244]
#  [ 77.16500092]
#  [ 79.71250153]
#  [ 80.36250305]
#  [ 81.30249786]
#  [ 80.00749969]
#  [ 80.38749695]
#  [ 79.90249634]
#  [ 81.80000305]
#  [ 81.21749878]
#  [ 81.23750305]
#  [ 79.75      ]
#  [ 80.90499878]
#  [ 80.07499695]
#  [ 78.26249695]
#  [ 74.54499817]
#  [ 72.01999664]
#  [ 73.16249847]
#  [ 68.37999725]
#  [ 68.33999634]
#  [ 74.70249939]
#  [ 72.33000183]
#  [ 75.68499756]
#  [ 73.23000336]
#  [ 72.25749969]
#  [ 66.54250336]
#  [ 71.33499908]
#  [ 68.85749817]
#  [ 62.05749893]
#  [ 69.49250031]
#  [ 60.55250168]
#  [ 63.21500015]
#  [ 61.66749954]
#  [ 61.19499969]
#  [ 57.31000137]
# ...

# %%
X.shape
# Out:
# (203, 1)

# %%
y = np.array(AAPL_2020['Prediction'])[:-future_days]
print(y)
# Out:
# [ 60.55250168  63.21500015  61.66749954  61.19499969  57.31000137
#   56.09249878  61.72000122  61.38000107  64.61000061  61.93500137
#   63.70249939  63.57249832  60.22750092  61.23249817  60.35250092
#   65.61750031  64.85749817  66.51750183  66.99749756  68.3125
#   71.76249695  71.10749817  71.67250061  70.69999695  69.23249817
#   67.09249878  69.02500153  68.75749969  70.74250031  70.79250336
#   69.64499664  71.93250275  73.44999695  72.26750183  73.29000092
#   74.38999939  75.15750122  75.93499756  77.53250122  78.75250244
#   77.85250092  76.91249847  77.38500214  76.92749786  78.73999786
#   78.28500366  79.80750275  79.21250153  79.72250366  79.18250275
#   79.52749634  79.5625      79.48500061  80.46250153  80.83499908
#   81.27999878  80.58000183  82.875       83.36499786  85.99749756
#   88.20999908  83.97499847  84.69999695  85.74749756  88.01999664
#   87.89749908  87.93250275  87.43000031  89.71749878  91.63249969
# ...

# %%
y.shape
# Out:
# (203,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
from sklearn.linear_model import LinearRegression

# %%
# Implementing Linear Regression Algorithms:
lr = LinearRegression().fit(x_train, y_train)

# %%
x_future = AAPL_2020.drop(['Prediction'], 1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
x_future
# Out:
# array([[109.375     ],
#        [113.01000214],
#        [115.01000214],
#        [114.90750122],
#        [114.60749817],
#        [115.5625    ],
#        [115.70749664],
#        [118.27500153],
#        [124.37000275],
#        [125.85749817],
#        [124.82499695],
#        [126.52249908],
#        [125.01000214],
#        [124.80750275],
#        [129.03999329],
#        [134.17999268],
#        [131.3999939 ],
#        [120.87999725],
#        [120.95999908],
#        [112.81999969],
#        [117.31999969],
#        [113.48999786],
#        [112.        ],
#        [115.36000061],
#        [115.54000092],
#        [112.12999725],
#        [110.33999634],
#        [106.83999634],
#        [110.08000183],
#        [111.80999756],
#        [107.12000275],
#        [108.22000122],
#        [112.27999878],
#        [114.95999908],
#        [114.08999634],
#        [115.80999756],
#        [116.79000092],
#        [113.01999664],
#        [116.5       ],
#        [113.16000366],
# ...

# %%
lr_prediction = lr.predict(x_future)
print(lr_prediction)
# Out:
# [115.59029841 118.40124478 119.94784435 119.86858041 119.63658812
#  120.37509083 120.4872167  122.47266767 127.18593081 128.3362107
#  127.53777773 128.85045576 127.6808422  127.52424946 130.79723349
#  134.77199391 132.62222145 124.48711031 124.54897571 118.25431593
#  121.73416496 118.77242537 117.62021034 120.21849809 120.35769229
#  117.72073719 116.33652987 113.62998062 116.13547617 117.4732815
#  113.84650952 114.6971381  117.83673334 119.909177   119.23640406
#  120.56648064 121.32431702 118.40897353 121.10005938 118.51724093
#  120.0019751  119.91691165 121.46351122 127.20912886 124.65723721
#  124.72683726 124.35565076 123.04877224 120.69794608 121.88109381]

# %%
predictions = lr_prediction
valid = AAPL_2020[(X.shape[0]):]
valid['Predictions'] = predictions
# Out:
# C:\Users\ASUS\AppData\Local\conda\conda\envs\HCIA_AI\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(12,8))
plt.title("Apple's Stock Price Prediction Model(Linear Regression Model)")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
plt.plot(AAPL_2020['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(["Original", "Valid", 'Predicted'])
plt.show()

# %%
# Visually show the stock price / Adjusted Close
plt.figure(figsize=(15,10))
plt.plot(AAPL_2020['Close'], label='Close', alpha=1)
plt.title('APPL Close Price History')
plt.xlabel('Date')
plt.ylabel('Close Price USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,7))
#scatterplot for both set of data
plt.scatter(x_test, y_test, color='green',label='test')
plt.scatter(x_train, y_train, color='blue',label='train')

# %%
sns.kdeplot(y_test, shade=True)
sns.kdeplot(y, shade=True)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree = DecisionTreeRegressor().fit(x_train, y_train)

# %%
x_future = AAPL_2020.drop(['Prediction'], 1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
x_future
# Out:
# array([[109.375     ],
#        [113.01000214],
#        [115.01000214],
#        [114.90750122],
#        [114.60749817],
#        [115.5625    ],
#        [115.70749664],
#        [118.27500153],
#        [124.37000275],
#        [125.85749817],
#        [124.82499695],
#        [126.52249908],
#        [125.01000214],
#        [124.80750275],
#        [129.03999329],
#        [134.17999268],
#        [131.3999939 ],
#        [120.87999725],
#        [120.95999908],
#        [112.81999969],
#        [117.31999969],
#        [113.48999786],
#        [112.        ],
#        [115.36000061],
#        [115.54000092],
#        [112.12999725],
#        [110.33999634],
#        [106.83999634],
#        [110.08000183],
#        [111.80999756],
#        [107.12000275],
#        [108.22000122],
#        [112.27999878],
#        [114.95999908],
#        [114.08999634],
#        [115.80999756],
#        [116.79000092],
#        [113.01999664],
#        [116.5       ],
#        [113.16000366],
# ...

# %%
tree_prediction = tree.predict(x_future)
print(tree_prediction)
# Out:
# [116.87000275 127.80999756 126.66000366 115.05000305 116.59999847
#  111.19999695 115.31999969 108.86000061 108.76999664 110.44000244
#  114.94999695 119.02999878 118.69000244 116.31999969 119.20999908
#  119.48999786 119.20999908 119.26000214 120.30000305 117.51000214
#  118.02999878 127.80999756 117.33999634 113.84999847 115.16999817
#  116.02999878 116.58999634 119.05000305 122.72000122 117.33999634
#  122.94000244 122.25       123.75       124.37999725 121.77999878
#  123.23999786 122.41000366 127.80999756 127.87999725 127.80999756
#  128.69999695 126.66000366 128.22999573 108.76999664 130.96000671
#  130.96000671 119.26000214 134.86999512 133.72000122 132.69000244]

# %%
predictions = tree_prediction 
valid = AAPL_2020[X.shape[0]:]
valid['Predictions'] = predictions
# Out:
# C:\Users\ASUS\AppData\Local\conda\conda\envs\HCIA_AI\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(12,8))
plt.title("Apple's Stock Price Prediction Model(Decision Tree Regressor Model)")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
plt.plot(AAPL_2020['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(["Original", "Valid", 'Predicted'])
plt.show()

# %%
# Visually show the stock price / Adjusted Close
plt.figure(figsize=(15,10))
plt.plot(AAPL_2020['Close'], label='Close', alpha=1)
plt.title('APPL Close Price History')
plt.xlabel('Date')
plt.ylabel('Close Price USD ($) ')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %%
sns.kdeplot(y_test, shade=True)
sns.kdeplot(y, shade=True)
