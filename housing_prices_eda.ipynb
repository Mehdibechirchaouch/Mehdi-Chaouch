# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehdibechirchaouch/Mehdi-Chaouch/blob/main/housing_prices_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Housing Prices - EDA

# %% [markdown]
# #### I am a Data Science enthusiast that is very passionate and motivated. In this notebook, I will focus on analyzing the data pertaining to the House Prices - Advanced Regression Techniques problem and will showcase my progress step by step until I present my own conclusion for this problem.
#
# #### If you found this Kernel insightful, please consider upvoting it 👍
#
# #### I am all ears if you have any advice :)

# %% [markdown]
# <img src= "https://storage.googleapis.com/kaggle-competitions/kaggle/5407/media/housesbanner.png" alt ="Houses" style='width: 85%; margin-left: 7.5%
# '>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            background-color:#B1E1FF;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            display:flex;
#            flex-direction: row;
#            border-radius: 0.25rem;
#            border-width: 0.25rem;
#            border-style: solid;
#            border-color: #256D85">
#
# <h1 style="padding: 2rem;
#           color:black;
#           text-align:center;
#           margin:0 auto;
#           font-size:3rem;">
#    THE NOTEBOOK CONTAINS THE FOLLOWING SECTIONS:
# </h1>
#
# </div>

# %% [markdown]
# <div id=1 style="color:white;
#            display:fill;
#            border-radius:10px;
#            background-color:#3EC70B;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            display:flex;
#            justify-content:center;
#            border-width: 0.25rem;
#            border-style: solid;
#            border-color: #256D85">
#
# <h1 style="padding: 2.5rem;
#           color:white;
#           text-align:center;
#           margin:0 auto;
#           font-size:3rem;">
#    Problem Description
# </h1>
# </div>

# %% [markdown]
# <div id = 2 style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            display:flex;
#            justify-content:center;
#            border-width: 0.2rem;
#            border-style: solid;
#            border-color: #7A86B6">
#
# <h2 style="padding: 2rem;
#            color:white;
#            text-align:center;
#            margin:0 auto;">
# Objective ⛳
# </h2>
# </div>

# %% [markdown]
# The Housing Prices - Advanced Regression Techniques Competition wants the participants to predict the price of a house. In order to make these predictions, we are provided with both training and testing sets to which we will both apply EDA, data preprocessing, and also build models in order to reach our end goal.
#
# Without further due, lets get started.

# %% [markdown]
# <div id = 2 style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            display:flex;
#            justify-content:center;
#            border-width: 0.2rem;
#            border-style: solid;
#            border-color: #7A86B6">
#
# <h2 style="padding: 2rem;
#            color:white;
#            text-align:center;
#            margin:0 auto;">
# Variables of our given datasets 📁📂
# </h2>
# </div>

# %% [markdown]
# * **SalePrice** - the property's sale price in dollars. This is the target variable that you're trying to predict.
#
# * **MSSubClass**: The building class
#
# * **MSZoning**: The general zoning classification
#
# * **LotFrontage**: Linear feet of street connected to property
#
# * **LotArea**: Lot size in square feet
#
# * Street: Type of road access
#
# * Alley: Type of alley access
#
# * LotShape: General shape of property
# * LandContour: Flatness of the property
# * Utilities: Type of utilities available
# * LotConfig: Lot configuration
# * LandSlope: Slope of property
# * Neighborhood: Physical locations within Ames city limits
# * Condition1: Proximity to main road or railroad
# * Condition2: Proximity to main road or railroad (if a second is present)
# * BldgType: Type of dwelling
# * HouseStyle: Style of dwelling
# * OverallQual: Overall material and finish quality
# * OverallCond: Overall condition rating
# * YearBuilt: Original construction date
# * YearRemodAdd: Remodel date
# * RoofStyle: Type of roof
# * RoofMatl: Roof material
# * Exterior1st: Exterior covering on house
# * Exterior2nd: Exterior covering on house (if more than one material)
# * MasVnrType: Masonry veneer type
# * MasVnrArea: Masonry veneer area in square feet
# * ExterQual: Exterior material quality
# * ExterCond: Present condition of the material on the exterior
# * Foundation: Type of foundation
# * BsmtQual: Height of the basement
# * BsmtCond: General condition of the basement
# * BsmtExposure: Walkout or garden level basement walls
# * BsmtFinType1: Quality of basement finished area
# * BsmtFinSF1: Type 1 finished square feet
# * BsmtFinType2: Quality of second finished area (if present)
# * BsmtFinSF2: Type 2 finished square feet
# * BsmtUnfSF: Unfinished square feet of basement area
# * TotalBsmtSF: Total square feet of basement area
# * Heating: Type of heating
# * HeatingQC: Heating quality and condition
# * CentralAir: Central air conditioning
# * Electrical: Electrical system
# * 1stFlrSF: First Floor square feet
# * 2ndFlrSF: Second floor square feet
# * LowQualFinSF: Low quality finished square feet (all floors)
# * GrLivArea: Above grade (ground) living area square feet
# * BsmtFullBath: Basement full bathrooms
# * BsmtHalfBath: Basement half bathrooms
# * FullBath: Full bathrooms above grade
# * HalfBath: Half baths above grade
# * Bedroom: Number of bedrooms above basement level
# * Kitchen: Number of kitchens
# * KitchenQual: Kitchen quality
# * TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# * Functional: Home functionality rating
# * Fireplaces: Number of fireplaces
# * FireplaceQu: Fireplace quality
# * GarageType: Garage location
# * GarageYrBlt: Year garage was built
# * GarageFinish: Interior finish of the garage
# * GarageCars: Size of garage in car capacity
# * GarageArea: Size of garage in square feet
# * GarageQual: Garage quality
# * GarageCond: Garage condition
# * PavedDrive: Paved driveway
# * WoodDeckSF: Wood deck area in square feet
# * OpenPorchSF: Open porch area in square feet
# * EnclosedPorch: Enclosed porch area in square feet
# * 3SsnPorch: Three season porch area in square feet
# * ScreenPorch: Screen porch area in square feet
# * PoolArea: Pool area in square feet
# * PoolQC: Pool quality
#
# * Fence: Fence quality
#
# * MiscFeature: Miscellaneous feature not covered in other categories
#
# * MiscVal: $Value of miscellaneous feature
#
# * MoSold: Month Sold
#
# * YrSold: Year Sold
#
# * SaleType: Type of sale
#
# * SaleCondition: Condition of sale

# %% [markdown]
# <div id = 4 style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            display:flex;
#            justify-content:center;
#            border-width: 0.2rem;
#            border-style: solid;
#            border-color: #7A86B6">
#
# <h2 style="padding: 2rem;
#            color:white;
#            text-align:center;
#            margin:0 auto;">
# Evaluation Metrics Used 📏
# </h2>
# </div>

# %% [markdown]
# ### Based on the problem, we will use the Mean Squared Error metric, which is ideal for regression problems.
#
# $MSE = 1/n \sum_{i=1}^{D}(y_i-\hat{y_i})^2$
#
# Read the following if you are interested in other possible metrics for the ML regression tasks:
# https://medium.com/analytics-vidhya/common-loss-functions-in-machine-learning-for-a-regression-model-27d2bbda9c93

# %% [markdown]
# <div id=5 style="color:white;
#            display:fill;
#            border-radius:10px;
#            background-color:#3EC70B;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            display:flex;
#            justify-content:center;
#            border-width: 0.25rem;
#            border-style: solid;
#            border-color: #256D85">
#
# <h1 style="padding: 2.5rem;
#           color:white;
#           text-align:center;
#           margin:0 auto;
#           font-size:3rem;">
#    Work 🔨
# </h1>
# </div>

# %% [markdown]
# <div id = 6 style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            display:flex;
#            justify-content:center;
#            border-width: 0.2rem;
#            border-style: solid;
#            border-color: #7A86B6">
#
# <h2 style="padding: 2rem;
#            color:white;
#            text-align:center;
#            margin:0 auto;">
# Importing relevant libraries 📚📚📚
# </h2>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from termcolor import colored
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder, StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <div id=7 style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            display:flex;
#            justify-content:center;
#            border-width: 0.2rem;
#            border-style: solid;
#            border-color: #7A86B6      ">
#
# <h2 style="padding: 2rem;
#               color:white;
#           text-align:center;
#           margin:0 auto;
#           ">
# Reading Data 📖
# </h2>
# </div>

# %%
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test (1).csv")

# %% [markdown]
# <div style="
#             display:flex;
#             flex-direction:row">
# <div style="width:0.05%;
#             height:max;
#             background-color:#5642C5;
#             padding:0.75rem;
#             border-top-left-radius:0.5rem;
#             border-bottom-left-radius: 0.5rem">
#
# </div>
# <div id=7 style="color:white;
#            background-color:#9BA3EB;
#            font-size:70%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            border-width: 0.2rem;
#            border-style: solid;
#            border-color: #7A86B6;
#            display: inline-block;
#            flex-direction: row;
#            border-left: none
#                  ">
#
# <h2 style="padding: 0.5rem;
#            color:white;
#            text-align:left;
#            margin-right: auto;
#           ">
# Train data 📁
# </h2>
# </div>
# </div>

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# <div style="
#             display:flex;
#             flex-direction:row">
# <div style="width:0.05%;
#             height:max;
#             background-color:#5642C5;
#             padding:0.75rem;
#             border-top-left-radius:0.5rem;
#             border-bottom-left-radius: 0.5rem">
#
# </div>
# <div id=7 style="color:white;
#            background-color:#9BA3EB;
#            font-size:70%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            border-width: 0.2rem;
#            border-style: solid;
#            border-color: #7A86B6;
#            display: inline-block;
#            flex-direction: row;
#            border-left: none
#                  ">
#
# <h2 style="padding: 0.5rem;
#            color:white;
#            text-align:left;
#            margin-right: auto;
#           ">
# Test data 📁
# </h2>
# </div>
# </div>

# %%
test_data.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# <div id=7 style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            display:flex;
#            justify-content:center;
#            border-width: 0.2rem;
#            border-style: solid;
#            border-color: #7A86B6      ">
#
# <h2 style="padding: 2rem;
#               color:white;
#           text-align:center;
#           margin:0 auto;
#           ">
# EDA 🔍 📊
# </h2>
# </div>

# %% [markdown]
# <div id=9 style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            background-color:#3EC70B;
#            font-family:Verdana;
#            letter-spacing:1px;
#            display:flex;
#            justify-content:center;
#            border-width: 0.25rem;
#            border-style: solid;
#            border-color: #256D85">
#
# <h3 style="text-align:center;
#           margin:0 auto;
#           color:white;
#            padding:1rem
#           ">
# View Data Types of Predictors and Target Variables
# </h3>
# </div>

# %%
print(colored(f'DATA TYPES:', 'cyan', attrs=['bold', 'underline']))
print(train_data.dtypes[:])
# Out:
# DATA TYPES:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
print('TRAIN DATA')
print(colored(f'Number of rows in train data: {train_data.shape[0]}', 'cyan'))
print(colored(f'Number of columns in train data: {train_data.shape[1]}\n', 'cyan'))
print("TEST DATA")
print(colored(f'Number of rows in test data: {test_data.shape[0]}', 'green'))
print(colored(f'Number of columns in test data: {test_data.shape[1]}', 'green'))
# Out:
# TRAIN DATA
# Number of rows in train data: 1460
# Number of columns in train data: 81
#
# TEST DATA
# Number of rows in test data: 1459
# Number of columns in test data: 80

# %% [markdown]
# <div id=10 style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            background-color:#3EC70B;
#            font-family:Verdana;
#            letter-spacing:1px;
#            display:flex;
#            justify-content:center;
#            border-width: 0.25rem;
#            border-style: solid;
#            border-color: #256D85">
#
# <h3 style="text-align:center;
#           margin:0 auto;
#           color:white;
#            padding:1rem
#           ">
# Presence of Missing Values ⚠️
# </h3>
# </div>

# %%
train_data.isnull().sum().sum(), test_data.isnull().sum().sum()
# Out:
# (6965, 7000)

# %% [markdown]
# There are a total of 6965 missing values for the training data and 7000 missing values for the testing data

# %%
TRAIN_NA_COLS = list(train_data.columns[train_data.isnull().any()])
TRAIN_NA_COUNT = train_data[TRAIN_NA_COLS].isna().sum()

plt.figure(figsize=(19,8))
sns.barplot(y=TRAIN_NA_COUNT[:10], x=TRAIN_NA_COLS[:10], palette='mako')
plt.show()

plt.figure(figsize=(19,8))
sns.barplot(y=TRAIN_NA_COUNT[10:], x=TRAIN_NA_COLS[10:], palette='mako')
plt.show()
print(colored("TRAIN DATA COLUMNS WITH MISSING VALUES:\n", 'magenta', attrs=['bold', 'underline']))
TRAIN_NA_COUNT
# Out:
# TRAIN DATA COLUMNS WITH MISSING VALUES:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# These are the columns that have missing values in the training data.

# %%
# sns.countplot(train_data, x=train_data.columns[train_data.isnull().any()])
TEST_NA_COLS = list(test_data.columns[test_data.isna().any()])
TEST_NA_COUNT = test_data[TEST_NA_COLS].isna().sum()

plt.figure(figsize=(19,8))
sns.barplot(y=TEST_NA_COUNT[:15], x=TEST_NA_COLS[:15], palette='mako')
plt.show()

plt.figure(figsize=(19,8))
sns.barplot(y=TEST_NA_COUNT[15:], x=TEST_NA_COLS[15:], palette='mako')
plt.show()
print(colored("TEST DATA COLUMNS WITH MISSING VALUES:\n", 'magenta', attrs=['bold', 'underline']))
TEST_NA_COUNT
# Out:
# TEST DATA COLUMNS WITH MISSING VALUES:
# MSZoning           4
# LotFrontage      227
# Alley           1352
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# MasVnrType        16
# MasVnrArea        15
# BsmtQual          44
# BsmtCond          45
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinSF1         1
# BsmtFinType2      42
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# FireplaceQu      730
# GarageType        76
# GarageYrBlt       78
# GarageFinish      78
# GarageCars         1
# GarageArea         1
# GarageQual        78
# GarageCond        78
# PoolQC          1456
# Fence           1169
# MiscFeature     1408
# SaleType           1
# dtype: int64

# %% [markdown]
# These are the columns that have missing values in the test data.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:1px;
#            display:flex;
#             justify-content:center;">
#
# <h4 style="text-align:center;
#           margin:0 auto;
#           color:black;
#           ">
# Conclusions 📍
# </h4>
# </div>
#
# * There are many columns with missing values.
# * The testing set has more missing values which is somewhat inconvenient.
# * This issue will be handled accordingly in a future section.
# * PoolQC, Alley, Fence, MiscFeatue are the predictors that present the most missing values in both training and testing sets.

# %% [markdown]
# <div id=11 style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            background-color:#3EC70B;
#            font-family:Verdana;
#            letter-spacing:1px;
#            display:flex;
#            justify-content:center;
#            border-width: 0.25rem;
#            border-style: solid;
#            border-color: #256D85">
#
# <h3 style="text-align:center;
#           margin:0 auto;
#           color:white;
#            padding:1rem
#           ">
#  Data Analysis of Individual Predictors 🔎
# </h3>
# </div>

# %% [markdown]
# <div style="
#             display:flex;
#             flex-direction:row">
# <div style="width:0.05%;
#             height:max;
#             background-color:#54B435;
#             padding:0.75rem;
#             border-top-left-radius:0.5rem;
#             border-bottom-left-radius: 0.5rem">
#
# </div>
# <div id=7 style="color:white;
#            background-color:#82CD47;
#            font-size:70%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            border-width: 0.2rem;
#            border-style: solid;
#            border-color: #7A86B6;
#            display: inline-block;
#            flex-direction: row;
#            border-left: none
#                  ">
#
# <h2 style="padding: 0.5rem;
#            color:white;
#            text-align:left;
#            margin-right: auto;
#           ">
# Sale Price 💲🏠
# </h2>
# </div>
# </div>

# %%
train_data['SalePrice'].mean()
train_data['SalePrice'].min()
train_data['SalePrice'].max()
train_data['SalePrice'].mode()[0]
sns.displot(train_data, x="SalePrice")
plt.title('Distribution Plot of the SalePrice target variable')
plt.show()
print(colored("Sales Price Statistics:\n", 'magenta', attrs=['bold', 'underline']))
print(colored('The mean value of the Sale Price is: ', "cyan", attrs=['bold']),train_data['SalePrice'].mean(),'\n')
print(colored('The maximum value of the Sale Price is: ', "cyan", attrs=['bold']),train_data['SalePrice'].max(),'\n')
print(colored('The minimum value of the Sale Price is: ', "cyan", attrs=['bold']),train_data['SalePrice'].min(),'\n')
print(colored('The mode value of the Sale Price is: ', "cyan", attrs=['bold']),train_data['SalePrice'].mode()[0],'\n')
# Out:
# Sales Price Statistics:
#
# The mean value of the Sale Price is:  180921.19589041095
#
# The maximum value of the Sale Price is:  755000
#
# The minimum value of the Sale Price is:  34900
#
# The mode value of the Sale Price is:  140000

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:1px;
#            display:flex;
#             justify-content:center;">
#
# <h4 style="text-align:center;
#           margin:0 auto;
#           color:black;
#           ">
# Conclusions 📍
# </h4>
# </div>
#
# * The Target variable follows a normal distribution, therefore we will apply Standardization when performing data preprocessing

# %% [markdown]
# <div style="
#             display:flex;
#             flex-direction:row">
# <div style="width:0.05%;
#             height:max;
#             background-color:#54B435;
#             padding:0.75rem;
#             border-top-left-radius:0.5rem;
#             border-bottom-left-radius: 0.5rem">
#
# </div>
# <div id=7 style="color:white;
#            background-color:#82CD47;
#            font-size:70%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            border-width: 0.2rem;
#            border-style: solid;
#            border-color: #7A86B6;
#            display: inline-block;
#            flex-direction: row;
#            border-left: none
#                  ">
#
# <h2 style="padding: 0.5rem;
#            color:white;
#            text-align:left;
#            margin-right: auto;
#           ">
# MSSubClass (building subclass) 🏦
# </h2>
# </div>
# </div>

# %%
sns.barplot(x=np.unique(train_data['MSSubClass']), y=train_data['MSSubClass'].value_counts(), palette='mako')
plt.show()

print(colored("Value Counts based on MSSubClass:\n", 'green', attrs=['underline', 'bold']))
print(colored(train_data['MSSubClass'].value_counts(), "cyan", attrs=['bold']))
# Out:
# Value Counts based on MSSubClass:
#
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:1px;
#            display:flex;
#             justify-content:center;">
#
# <h4 style="text-align:center;
#           margin:0 auto;
#           color:black;
#           ">
# Conclusions 📍
# </h4>
# </div>
#
# * The value 20 for MSSubClass has the highest number of isntances, while the value 190 has the lowest.
# * We will use label encoding to preprocess our data.

# %% [markdown]
# <div style="
#             display:flex;
#             flex-direction:row">
# <div style="width:0.05%;
#             height:max;
#             background-color:#54B435;
#             padding:0.75rem;
#             border-top-left-radius:0.5rem;
#             border-bottom-left-radius: 0.5rem">
#
# </div>
# <div id=7 style="color:white;
#            background-color:#82CD47;
#            font-size:70%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            border-width: 0.2rem;
#            border-style: solid;
#            border-color: #7A86B6;
#            display: inline-block;
#            flex-direction: row;
#            border-left: none
#                  ">
#
# <h2 style="padding: 0.5rem;
#            color:white;
#            text-align:left;
#            margin-right: auto;
#           ">
# MSZoning
# </h2>
# </div>
# </div>

# %%
sns.barplot(x=np.unique(train_data['MSZoning']), y=train_data['MSZoning'].value_counts(), palette='mako')
plt.show()

print(colored("Value Counts based on MSZoning:\n", 'green', attrs=['underline', 'bold']))
print(colored(train_data['MSZoning'].value_counts(), "cyan", attrs=['bold']))
# Out:
# Value Counts based on MSZoning:
#
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:1px;
#            display:flex;
#             justify-content:center;">
#
# <h4 style="text-align:center;
#           margin:0 auto;
#           color:black;
#           ">
# Conclusions 📍
# </h4>
# </div>
#
# * C (all) has the higest count and RM has the least
# * We will use label encoding to preprocess our data.

# %% [markdown]
# ## We will now speed up the EDA by evaluating specific datatypes. This is solely done because there are too many predictors.

# %%
train_data.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('O'), dtype('float64')], dtype=object)

# %% [markdown]
# We have int64, O, and float64 dtypes

# %% [markdown]
# <div style="
#             display:flex;
#             flex-direction:row">
# <div style="width:0.05%;
#             height:max;
#             background-color:#54B435;
#             padding:0.75rem;
#             border-top-left-radius:0.5rem;
#             border-bottom-left-radius: 0.5rem">
#
# </div>
# <div id=7 style="color:white;
#            background-color:#82CD47;
#            font-size:70%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            border-width: 0.2rem;
#            border-style: solid;
#            border-color: #7A86B6;
#            display: inline-block;
#            flex-direction: row;
#            border-left: none
#                  ">
#
# <h2 style="padding: 0.5rem;
#            color:white;
#            text-align:left;
#            margin-right: auto;
#           ">
# Float Predictors
# </h2>
# </div>
# </div>

# %% [markdown]
# ### Float predictors include:
# * LotFrontage
# * MasVnrArea
# * GarageYrBlt

# %%
FLOAT_COLS = train_data.columns[train_data.dtypes == 'float64']
train_data[FLOAT_COLS] = train_data[FLOAT_COLS].fillna(0.)
print(FLOAT_COLS)
fig, axes = plt.subplots(2, 2)
fig.delaxes(axes[1][1])
fig.set_figheight(8)
fig.set_figwidth(12)
axes[0, 0].set_title(FLOAT_COLS[0])
axes[0, 1].set_title(FLOAT_COLS[1])
axes[1, 0].set_title(FLOAT_COLS[2])
sns.distplot(train_data, x=train_data[FLOAT_COLS[0]], ax=axes[0,0])
sns.distplot(train_data, x=train_data[FLOAT_COLS[1]], ax=axes[0,1])
sns.distplot(train_data, x=train_data[FLOAT_COLS[2]], ax=axes[1,0])
fig.show()
# Out:
# Index(['LotFrontage', 'MasVnrArea', 'GarageYrBlt'], dtype='object')

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:1px;
#            display:flex;
#             justify-content:center;">
#
# <h4 style="text-align:center;
#           margin:0 auto;
#           color:black;
#           ">
# Conclusions 📍
# </h4>
# </div>
#
# * LotFrontage follows a normal distribution, therefore applying standard scaling seems to eb a good choice.
# * MasVnrArea and GarageYearBlt don't follow a normal distribution, therefore we can apply standard scaling

# %% [markdown]
# <div style="
#             display:flex;
#             flex-direction:row">
# <div style="width:0.05%;
#             height:max;
#             background-color:#54B435;
#             padding:0.75rem;
#             border-top-left-radius:0.5rem;
#             border-bottom-left-radius: 0.5rem">
#
# </div>
# <div id=7 style="color:white;
#            background-color:#82CD47;
#            font-size:70%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            border-width: 0.2rem;
#            border-style: solid;
#            border-color: #7A86B6;
#            display: inline-block;
#            flex-direction: row;
#            border-left: none
#                  ">
#
# <h2 style="padding: 0.5rem;
#            color:white;
#            text-align:left;
#            margin-right: auto;
#           ">
# Object Predictors
# </h2>
# </div>
# </div>

# %%
OBJECT_COLS = train_data.columns[train_data.dtypes == 'O'][1:] # Start from 1 since index 0 is MSZoning
OBJECT_COLS_DATA = train_data[OBJECT_COLS]
train_data[OBJECT_COLS] = train_data[OBJECT_COLS].fillna('None')
fig, axes = plt.subplots(21, 2)
fig.set_figheight(50)
fig.set_figwidth(38)
idx = 0
for i in range(21):
    for j in range(2):
        sns.barplot(x=np.unique(train_data[OBJECT_COLS[idx]]), y=train_data[OBJECT_COLS[idx]].value_counts(), ax=axes[i,j], palette='mako')
        axes[i, j].set_title(OBJECT_COLS[idx])
        idx += 1
        
        
fig.show()

# %% [markdown]
# <div style="
#             display:flex;
#             flex-direction:row">
# <div style="width:0.05%;
#             height:max;
#             background-color:#54B435;
#             padding:0.75rem;
#             border-top-left-radius:0.5rem;
#             border-bottom-left-radius: 0.5rem">
#
# </div>
# <div id=7 style="color:white;
#            background-color:#82CD47;
#            font-size:70%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            border-width: 0.2rem;
#            border-style: solid;
#            border-color: #7A86B6;
#            display: inline-block;
#            flex-direction: row;
#            border-left: none
#                  ">
#
# <h2 style="padding: 0.5rem;
#            color:white;
#            text-align:left;
#            margin-right: auto;
#           ">
# Integer Predictors
# </h2>
# </div>
# </div>

# %%
INT_COLS = train_data.columns[train_data.dtypes == 'int64'][1:-1] # Skip Id and Sale
INT_COLS_DATA = train_data[INT_COLS]
fig, axes = plt.subplots(17, 2)
fig.delaxes(axes[16][1])
fig.set_figheight(50)
fig.set_figwidth(38)
idx = 0
for i in range(17):
    for j in range(2):
        if idx != 33:
            sns.distplot(train_data, x=np.unique(train_data[INT_COLS[idx]]), ax=axes[i,j])
            axes[i, j].set_title(INT_COLS[idx])
            idx += 1

# %%
OBJECT_COLS = np.append(OBJECT_COLS, ['MSZoning'])
test_data[OBJECT_COLS] = test_data[OBJECT_COLS].fillna('None')

# %%
test_data[FLOAT_COLS] = test_data[FLOAT_COLS].fillna(0.)

# %%
test_data[INT_COLS] = test_data[INT_COLS].fillna(0)

# %%
test_data.MSZoning = test_data.MSZoning.fillna(0)

# %%
test_data.columns[test_data.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# <div id=7 style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            display:flex;
#            justify-content:center;
#            border-width: 0.2rem;
#            border-style: solid;
#            border-color: #7A86B6      ">
#
# <h2 style="padding: 2rem;
#               color:white;
#           text-align:center;
#           margin:0 auto;
#           ">
# Data Preprocessing
#
#
# </h2>
# </div>

# %% [markdown]
# Data preprocessing is an essential step in the Machine Learning lifecycle. It consists of applying transformations to our data such that we can use it for our models in later steps.

# %% [markdown]
# ### Defining full training set and test set

# %%
X_train, y_train = train_data[list(INT_COLS) + list(FLOAT_COLS) + list(OBJECT_COLS)], train_data['SalePrice']
X_test = test_data[list(INT_COLS) + list(FLOAT_COLS) + list(OBJECT_COLS)]

# %% [markdown]
# ### Label Encoding the Object predictors (Qualitative)

# %%
for col in OBJECT_COLS:
    le = LabelEncoder()
    print(X_train[col].unique())
    print(X_test[col].unique())
    X_train[col] = le.fit_transform(X_train[col])
    if 'None' not in le.classes_:
        le.classes_ = np.append(le.classes_, ['None'])
    X_test[col] = le.transform(X_test[col])
# Out:
# ['Pave' 'Grvl']
# ['Pave' 'Grvl']
# ['None' 'Grvl' 'Pave']
# ['None' 'Pave' 'Grvl']
# ['Reg' 'IR1' 'IR2' 'IR3']
# ['Reg' 'IR1' 'IR2' 'IR3']
# ['Lvl' 'Bnk' 'Low' 'HLS']
# ['Lvl' 'HLS' 'Bnk' 'Low']
# ['AllPub' 'NoSeWa']
# ['AllPub' 'None']
# ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# ['Inside' 'Corner' 'FR2' 'CulDSac' 'FR3']
# ['Gtl' 'Mod' 'Sev']
# ['Gtl' 'Mod' 'Sev']
# ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# ['NAmes' 'Gilbert' 'StoneBr' 'BrDale' 'NPkVill' 'NridgHt' 'Blmngtn'
#  'NoRidge' 'Somerst' 'SawyerW' 'Sawyer' 'NWAmes' 'OldTown' 'BrkSide'
#  'ClearCr' 'SWISU' 'Edwards' 'CollgCr' 'Crawfor' 'Blueste' 'IDOTRR'
#  'Mitchel' 'Timber' 'MeadowV' 'Veenker']
# ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# ...

# %% [markdown]
# ### Cell inspired from:
# https://www.kaggle.com/code/jesucristo/1-house-prices-solution-top-1/notebook?scriptVersionId=12846740

# %%
model = TSNE(n_components=2, random_state=0, perplexity=50)

train_data.columns

tsne = model.fit_transform(X_train)
std = StandardScaler()
s = std.fit_transform(X_train)
pca = PCA(n_components=35)
pca.fit(s)
pc = pca.transform(s)
kmeans = KMeans(n_clusters=5)
kmeans.fit(pc)

fr = pd.DataFrame({'tsne1': tsne[:,0], 'tsne2': tsne[:, 1], 'cluster': kmeans.labels_})
sns.lmplot(data=fr, x='tsne1', y='tsne2', hue='cluster', fit_reg=False)
print(np.sum(pca.explained_variance_ratio_))
# Out:
# 0.7676969083995471

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            background-color:#F4E06D;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px;
#            display:flex;
#            flex-direction: row;">
#
# <h1 style="padding: 2rem;
#           color:black;
#           text-align:center;
#           margin:0 auto;
#           font-size:3rem;">
#    WORK IN PROGRESS ⚠
# </h1>
#
# </div>
